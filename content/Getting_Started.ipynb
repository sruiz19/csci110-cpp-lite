// %% [markdown]
// # Welcome to CSCI 110
//
// Welcome to our interactive C++ coding environment!
//
// This notebook will help you learn how to:
//
// - Run code cells
// - Edit code
// - Restart the kernel
// - Save and download your work
// - Practice basic C++ programs

// %% [markdown]
// # Understanding Cells
//
// This notebook contains two types of cells:
//
// ## Markdown Cells
// These cells contain text, instructions, and explanations.
//
// ## Code Cells
// These cells contain C++ code that you can run and modify.
//
// To run a code cell, press Shift + Enter.

// %% [markdown]
// # Running Code
//
// To run a code cell:
//
// 1. Click inside the cell
// 2. Press **Shift + Enter**
//
// Try running the example below.

// %%
#include <iostream>

std::cout << "Hello, CSCI 110!" << std::endl;

// %% [markdown]
// # Important Note About C++ in JupyterLite
//
// This environment uses an interactive C++ notebook kernel.
//
// In this environment, we will often practice using smaller C++ code snippets instead of full programs with main().
//
// For larger assignments and complete programs, we will use OnlineGDB.

// %% [markdown]
// # Adding New Cells
//
// You can create your own cells in this notebook.
//
// To add a new cell:
//
// 1. Click the + button in the toolbar
// 2. Choose either:
//    - Code for C++ code
//    - Markdown for text and notes
//
// This allows you to experiment and practice your own code.

// %% [markdown]
// # Try It Yourself
//
// Modify the message below and run the cell again.
//
// Example ideas:
//
// - Change the text
// - Add your name
// - Print your favorite food
// - Print your favorite movie

// %%
#include <iostream>

std::cout << "Hello, CSCI 110!" << std::endl;
std::cout << "My favorite food is tacos!" << std::endl;

// %% [markdown]
// # Restarting the Kernel
//
// If your code stops working or you see a "redefinition of main" error:
//
// 1. Go to Kernel
// 2. Select Restart Kernel and Clear Outputs
// 3. Run your code again

// %% [markdown]
// # Downloading Your Work
//
// Your notebooks are stored in your browser while you are using JupyterLite.
//
// Because of this, it is important to regularly download your work to your computer.
//
// To download your notebook:
//
// 1. Go to **File**
// 2. Select **Download**
// 3. Save the `.ipynb` file to your computer
//
// It is a good idea to download your notebook before closing the browser or finishing your work session.

// %% [markdown]
// # Before You Leave
//
// Remember to download your notebook before closing the browser.

// %% [markdown]
// # You're Ready to Begin
//
// You now know how to:
//
// - Run code cells
// - Modify code
// - Restart the kernel
// - Download your work
//
// You are ready to begin exploring C++!
